# %% [markdown]
# What is Pandas?
#
# Python library used for working with structured data sets (tables). It has functions for analyzing, cleaning, exploring, and manipulating data. Similar to data tables in SQL and Excel.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\Sushant Gambhir\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\Sushant Gambhir\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Sushant Gambhir\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata in C:\Users\Sushant Gambhir\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in C:\Users\Sushant Gambhir\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# import pandas
import pandas as pd

# %%
pd.__version__ # check installed pandas version
# Out:
# '3.0.2'

# %% [markdown]
# ##### What is Dataframe?
# It's a structured data constructed with rows and columns, similar to a SQL tables or Excel tables
